# %%
import random

# The Coin class simulates a coin that can be flipped.

class Coin:
    
    # The __init__ method initializes the sideup data
    # attribute with 'Heads'
    
    def __init__(self):
        self.sideup = 'Heads'
        
    # The toss method generates a random number
    # in the range of 0 through 1. If the number
    # is 0, then sideup is set to 'Heads',
    # otherwise, sideup is set to 'Tails'.
    
    def toss(self):
        if random.randint(0, 1) == 0:
            self.sideup = 'Heads'
        else:
            self.sideup = 'Tails'
            
    # The get_sideup method returns the value 
    # referenced by sideup.
    
    def get_sideup(self):
        return self.sideup
    
# The main function 
def main():
    # Create an object from the Coin class
    my_coin = Coin()
    
    # Display the side of the coin that is facing up.
    print('This side is up:', my_coin.get_sideup())
    
    # Toss the coin.
    print("I'm tossing the coin...")
    my_coin.toss()
    
    # Display the side of the coin that is facing up.
    print('This side is up:', my_coin.get_sideup())
    
# Call the main function.
main()
# Out:
# This side is up: Heads
# I'm tossing the coin...
# This side is up: Tails

# %%
import random

# The Coin class simulates a coin that can be flipped.

class Coin:
    
    # The __init__ method initializes the sideup data
    # attribute with 'Heads'
    
    def __init__(self):
        self.sideup = 'Heads'
        
    # The toss method generates a random number
    # in the range of 0 through 1. If the number
    # is 0, then sideup is set to 'Heads',
    # otherwise, sideup is set to 'Tails'.
    
    def toss(self):
        if random.randint(0, 1) == 0:
            self.sideup = 'Heads'
        else:
            self.sideup = 'Tails'
            
    # The get_sideup method returns the value 
    # referenced by sideup.
    
    def get_sideup(self):
        return self.sideup
    
# The main function 
def main():
    # Create an object from the Coin class
    my_coin = Coin()
    
    # Display the side of the coin that is facing up.
    print('This side is up:', my_coin.get_sideup())
    
    # Toss the coin.
    print("I'm tossing the coin...")
    my_coin.toss()
    
    # But now I'm going to cheat! I'm going to 
    # directly change the value of the object's 
    # sideup attribute to 'Heads'
    my_coin.sideup = 'Heads'
    
    # Display the side of the coin that is facing up.
    print('This side is up:', my_coin.get_sideup())
    
# Call the main function.
main()
# Out:
# This side is up: Heads
# I'm tossing the coin...
# This side is up: Heads

# %%
import random

# The Coin class simulates a coin that can be flipped.

class Coin:
    
    # The __init__ method initializes the 
    # __sideup data attribute with 'Heads'
    
    def __init__(self):
        self.__sideup = 'Heads'
        
    # The toss method generates a random number
    # in the range of 0 through 1. If the number
    # is 0, then sideup is set to 'Heads',
    # otherwise, sideup is set to 'Tails'.
    
    def toss(self):
        if random.randint(0, 1) == 0:
            self.__sideup = 'Heads'
        else:
            self.__sideup = 'Tails'
            
    # The get_sideup method returns the value 
    # referenced by sideup.
    
    def get_sideup(self):
        return self.__sideup
    
# The main function 
def main():
    # Create an object from the Coin class
    my_coin = Coin()
    
    # Display the side of the coin that is facing up.
    print('This side is up:', my_coin.get_sideup())
    
    # Toss the coin.
    print("I'm going to toss the coin ten times:")
    for count in range(10):
        my_coin.toss()
        # my_coin.__sideup = 'Heads'
        print(my_coin.get_sideup())
    
# Call the main function.

main()
# Out:
# This side is up: Heads
# I'm going to toss the coin ten times:
# Tails
# Tails
# Tails
# Tails
# Heads
# Heads
# Tails
# Tails
# Heads
# Heads

# %%
# %run coin.py

# %%
# The program imports the coin module and
# creates an instance of the Coin class

import coin

def main():
    # Create an object from the Coin class
    my_coin = coin.Coin()
    
    # Display the side of the coin that is facing up.
    print('This side is up:', my_coin.get_sideup())
    
    # Toss the coin.
    print("I'm going to toss the coin ten times:")
    for count in range(10):
        my_coin.toss()
        # my_coin.__sideup = 'Heads'
        print(my_coin.get_sideup())
    
# Call the main function.
main()
# Out:
# This side is up: Heads
# I'm going to toss the coin ten times:
# Tails
# Tails
# Tails
# Heads
# Tails
# Heads
# Heads
# Tails
# Heads
# Heads

# %%
# %run bankaccount.py

# %%
# This program demonstrates the BankAccount class.

import bankaccount

def main():
    # Get the starting balance.
    start_bal = float(input('Enter your starting balance: '))

    # Create a BankAccount object.
    savings = bankaccount.BankAccount(start_bal)

    # Deposit the user's paycheck.
    pay = float(input('How much were you paid this week? '))
    print('I will deposit that into your account.')
    savings.deposit(pay)

    # Display the balance.
    print('Your account balance is ', \
          format(savings.get_balance(), ',.2f'), ' TL.',
          sep='')

    # Get the amount to withdraw.
    cash = float(input('How much would you like to withdraw? '))
    print('I will withdraw that from your account.')
    savings.withdraw(cash)

    # Display the balance.
    print('Your account balance is ', \
          format(savings.get_balance(), ',.2f'), ' TL.',
          sep='')

# Call the main function.
main()
# Out:
# Enter your starting balance: 3000.00
# How much were you paid this week? 1500.00
# I will deposit that into your account.
# Your account balance is 4,500.00 TL.
# How much would you like to withdraw? 5000.00
# I will withdraw that from your account.
# Error: Insufficient funds
# Your account balance is 4,500.00 TL.

# %%
# %run bankaccount2.py

# %%
# This program demonstrates the BankAccount class
# with the __str__ method added to it.

import bankaccount2

def main():
    # Get the starting balance.
    start_bal = float(input('Enter your starting balance: '))

    # Create a BankAccount object.
    savings = bankaccount2.BankAccount(start_bal)

    # Deposit the user's paycheck.
    pay = float(input('How much were you paid this week? '))
    print('I will deposit that into your account.')
    savings.deposit(pay)

    # Display the balance.
    print(savings)

    # Get the amount to withdraw.
    cash = float(input('How much would you like to withdraw? '))
    print('I will withdraw that from your account.')
    savings.withdraw(cash)

    # Display the balance.
    print(savings)
    
    # The __str__ method also called automatically
    # when an argument to the built-in str function.
    # This causes the BankAccount class's __str__
    # method to be called.
    
    account = bankaccount2.BankAccount(2250.50)
    message = str(account)
    print(message)

# Call the main function.
main()
# Out:
# Enter your starting balance: 3000.00
# How much were you paid this week? 1500.00
# I will deposit that into your account.
# The balance is 4,500.00 TL.
# How much would you like to withdraw? 5000.00
# I will withdraw that from your account.
# Error: Insufficient funds
# The balance is 4,500.00 TL.
# The balance is 2,250.50 TL.

# %%
# This program imports the simulation module and
# creates three instances of the Coin class.

import coin

def main():
    coin1 = coin.Coin()
    coin2 = coin.Coin()
    coin3 = coin.Coin()
    
    print('I have three coins with these sides up:')
    print(coin1.get_sideup())
    print(coin2.get_sideup())
    print(coin3.get_sideup())
    print()
    
    print("I'm tossing all three coins...")
    print()
    coin1.toss()
    coin2.toss()
    coin3.toss()
    
    print('Now here are the sides that are up:')
    print(coin1.get_sideup())
    print(coin2.get_sideup())
    print(coin3.get_sideup())
    print()
    
main()
# Out:
# I have three coins with these sides up:
# Heads
# Heads
# Heads
#
# I'm tossing all three coins...
#
# Now here are the sides that are up:
# Tails
# Tails
# Heads

# %%
# %run cellphone.py

# %%
# This program tests the Cellphone class.

import cellphone

def main():
    man = input('Enter the manufacturer: ')
    mod = input('Enter the model number: ')
    retail = float(input('Enter the retail price: '))
    
    phone = cellphone.CellPhone(man, mod, retail)
    
    print('Here is the data that you entered:')
    print('Manufacturer:', phone.get_manufact())
    print('Model Number:', phone.get_model())
    print('Retail Price:', format(phone.get_retail_price(), ',.2f'), ' TL', sep = '')

main()
# Out:
# Enter the manufacturer: ACM Electronics
# Enter the model number: 114
# Enter the retail price: 1789.99
# Here is the data that you entered:
# Manufacturer: ACM Electronics
# Model Number: 114
# Retail Price:1,789.99 TL

# %%
# This program creates CellPhone objects and 
# stores them in a list.

import cellphone

def main():
    phones = make_list()
    
    print()
    
    print('Here is the data you entered:')
    display_list(phones)
    
def make_list():
    phone_list = []
    amount = int(input('Please enter the amount of phones: '))
    
    print('Enter data for', amount, 'phones.')
    for count in range(1, amount+1):
        print('Phone number ' + str(count) + ':')
        man = input('Enter the manufacturer: ')
        mod = input('Enter the model number: ')
        retail = float(input('Enter the retail price: '))
        print()
        
        phone = cellphone.CellPhone(man, mod, retail)
        
        phone_list.append(phone)
        
    return phone_list

def display_list(phone_list):
    for item in phone_list:
        print(item.get_manufact())
        print(item.get_model())
        print(item.get_retail_price())
        print()
        
main()
# Out:
# Please enter the amount of phones: 5
# Enter data for 5 phones.
# Phone number 1:
# Enter the manufacturer: ACM Electronics
# Enter the model number: 114
# Enter the retail price: 1789.99
#
# Phone number 2:
# Enter the manufacturer: ACM Electronics
# Enter the model number: 11
# Enter the retail price: 1500.75
#
# Phone number 3:
# Enter the manufacturer: Wavelength Electronics
# Enter the model number: N477
# Enter the retail price: 2599.99
#
# Phone number 4:
# Enter the manufacturer: Alfa Communications
# Enter the model number: SLX55
# Enter the retail price: 2160.00
#
# Phone number 5:
# Enter the manufacturer: Sonic Systems
# Enter the model number: A1080
# Enter the retail price: 2374.99
#
#
# Here is the data you entered:
# ACM Electronics
# 114
# 1789.99
#
# ACM Electronics
# 11
# 1500.75
#
# Wavelength Electronics
# N477
# 2599.99
#
# Alfa Communications
# SLX55
# 2160.0
#
# Sonic Systems
# A1080
# 2374.99

# %%
import coin

def main():
    my_coin = coin.Coin()
    print(my_coin.get_sideup())  
    flip(my_coin)
    print(my_coin.get_sideup())
    
def flip(coin_obj):
    coin_obj.toss()

main()
# Out:
# Heads
# Tails

# %%
import pet

def main():
    pet_name = ""
    pet_type = ""
    pet_age = 0
    
    pet_name = input("Enter the name of your pet: ")
    pet_type = input("Enter the type of animal: ")
    pet_age = int(input("Enter the age of the pet: "))
    
    mypet = pet.Pet(pet_name, pet_type, pet_age)
    
    print("Here is the data that you entered: ")
    print("Pet name: ", mypet.get_name())
    print("Animal type: ", mypet.get_animal_type())
    print("Age of pet: ", mypet.get_age())
        
main()
# Out:
# Enter the name of your pet: Achille
# Enter the type of animal: Dog
# Enter the age of the pet: 5
# Here is the data that you entered:
# Pet name:  Achille
# Animal type:  Dog
# Age of pet:  5

# %%
class Square():
    def perimeter(self, side):
        return side * 4
    
    def area(self, side):
        return side * side
    
class Rectangle_1():
    
    def __init__(self):
        self.length = 10
        self.breadth = 15
        
    def getArea(self):
        return self.length * self.breadth
    
    def getPerimeter(self):
        return 2 * (self.length + self.breadth)
    
class Rectangle_2():
    
    def __init__(self):
        self.__length = 10
        self.__breadth = 15
        
    def getArea(self):
        return self.__length * self.__breadth
    
    def getPerimeter(self):
        return 2 * (self.__length + self.__breadth)
    
square = Square()
print(square.perimeter(15))
print(square.area(15))
print()
square_1 = Rectangle_1()
square_1.length, square_1.breadth = 10, 10
print(square_1.getPerimeter())
print(square_1.getArea())
print()
square_2 = Rectangle_2()
square_2.length, square_2.breadth = 10, 10
print(square_2.getPerimeter())
print(square_2.getArea())
# Out:
# 60
# 225
#
# 40
# 100
#
# 50
# 150

# %%
class Rectangle_3():
    
    def __init__(self, l, b):
        self.length = l
        self.breadth = b
        
    def getArea(self):
        return self.length * self.breadth
    
    def getPerimeter(self):
        return 2 * (self.length + self.breadth)
    
class Rectangle_4():
    
    def __init__(self, l, b):
        self.__length = l
        self.__breadth = b
        
    def getArea(self):
        return self.__length * self.__breadth
    
    def getPerimeter(self):
        return 2 * (self.__length + self.__breadth)
    
rectangle = Rectangle_3(10, 15)
rectangle.length, rectangle.breadth = 15, 20
print(rectangle.getPerimeter())
print(rectangle.getArea())
print()
rectangle_1 = Rectangle_4(10, 15)
print(rectangle_1.getPerimeter())
print(rectangle_1.getArea())
print()
rectangle_2 = Rectangle_4(10, 15)
rectangle_2.length, rectangle_2.breadth = 15, 20
print(rectangle_2.getPerimeter())
print(rectangle_2.getArea())
# Out:
# 70
# 300
#
# 50
# 150
#
# 50
# 150

# %%
import math as m

class Circle:
    
    def __init__(self, r):
        self.__radius = r
        
    def set_Perimeter(self, r):
        self.__radius = r
        
    def set_Area(self, r):
        self.__radius = r
        
    def get_Perimeter(self):
        return 2 * m.pi * self.__radius
    
    def get_Area(self):
        return m.pi * self.__radius ** 2
    
def main(radius = int(input("Enter the radius value: "))):
    my_circle = Circle(radius)
    print("The perimeter of Circle is: ", my_circle.get_Perimeter())
    return "The area of Circle is: {}".format(my_circle.get_Area())

print(main())
# Out:
# Enter the radius value: 5
# The perimeter of Circle is:  31.41592653589793
# The area of Circle is: 78.53981633974483
